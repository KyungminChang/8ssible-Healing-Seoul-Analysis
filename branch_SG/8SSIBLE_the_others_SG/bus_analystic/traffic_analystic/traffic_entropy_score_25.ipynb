# %% [markdown]
# # 엔트로피 가중치 기반 교통 지표 점수 산출
#
# 이 노트북은 네 개의 교통 관련 최종 지표를 따로 사용해 엔트로피 가중치를 계산하고, 자치구별 교통 지표 점수를 25점 만점으로 산출합니다.
#
# 사용 지표는 다음과 같습니다.
#
# - 대중교통점수: `transport_stress_score`
# - 출퇴근스트레스점수: `commute_stress_score`
# - 주차점수: `parking_score_100`
# - 민원점수: `complaint_score_100`
#
# 모든 점수는 높을수록 교통 문제가 큰 방향으로 해석합니다.

# %%
from pathlib import Path
import re
import numpy as np
import pandas as pd

def find_project_root(start=None):
    current = Path(start or Path.cwd()).resolve()
    for path in [current, *current.parents]:
        if (path / '.git').exists() and (path / 'branch_SG' / 'traffic_analystic').exists():
            return path
    raise FileNotFoundError('프로젝트 루트(branch_SG/traffic_analystic 포함)를 찾을 수 없습니다.')

BASE_DIR = find_project_root()
TRAFFIC_DIR = BASE_DIR / 'branch_SG' / 'traffic_analystic'
DATA_DIR = TRAFFIC_DIR / 'traffic_analystic_data'
OUT_DIR = TRAFFIC_DIR / 'outputs'
OUT_DIR.mkdir(parents=True, exist_ok=True)

BUS_PATH = DATA_DIR / 'bus_gu_wide_202605071519.csv'
SUBWAY_PATH = DATA_DIR / 'subway_gu_wide_202605071519.csv'
MONTHLY_PATH = DATA_DIR / 'monthly_scores_문헌기반_서울_202605071520.csv'
POPULATION_PATH = DATA_DIR / 'Garbage_collection_status.csv'
PARKING_COMPLAINT_PATH = OUT_DIR / 'gu_parking_complaint_score_summary.csv'

FINAL_SCORE_PATH = OUT_DIR / 'gu_traffic_entropy_score_25.csv'
FINAL_YEARLY_SCORE_PATH = OUT_DIR / 'gu_traffic_entropy_score_25_by_year.csv'
WEIGHT_PATH = OUT_DIR / 'traffic_entropy_weights.csv'

# %% [markdown]
# ## 1. 공통 함수
#
# `read_csv_smart`는 인코딩 차이를 흡수하기 위한 로더입니다. 엔트로피 가중치는 자치구 간 차이가 큰 지표에 더 큰 가중치를 부여하는 방식입니다.

# %%
def read_csv_smart(path, **kwargs):
    encodings = ['utf-8-sig', 'utf-8', 'cp949', 'euc-kr']
    last_error = None
    for enc in encodings:
        try:
            return pd.read_csv(path, encoding=enc, **kwargs)
        except Exception as exc:
            last_error = exc
    raise last_error

def pick_col(df, candidates=None, fallback_index=None, contains=None, label='column'):
    candidates = candidates or []
    cols = list(df.columns)
    for cand in candidates:
        if cand in cols:
            return cand
    if contains:
        for col in cols:
            text = str(col)
            if all(token in text for token in contains):
                return col
    if fallback_index is not None and fallback_index < len(cols):
        return cols[fallback_index]
    raise KeyError(f'{label} 컬럼을 찾을 수 없습니다. columns={cols}')

def rank_100(series):
    return series.rank(method='average', pct=True) * 100

def minmax_0_1(series):
    s = pd.to_numeric(series, errors='coerce')
    lo, hi = s.min(), s.max()
    if pd.isna(lo) or pd.isna(hi) or np.isclose(hi, lo):
        return pd.Series(0.5, index=s.index)
    return (s - lo) / (hi - lo)

def entropy_weights(matrix):
    x = matrix.astype(float).copy()
    x = x.apply(minmax_0_1, axis=0)
    eps = 1e-12
    p = x / (x.sum(axis=0) + eps)
    n = len(x)
    k = 1 / np.log(n)
    entropy = -k * (p * np.log(p + eps)).sum(axis=0)
    diversity = 1 - entropy
    if np.isclose(diversity.sum(), 0):
        weights = pd.Series(1 / len(diversity), index=diversity.index)
    else:
        weights = diversity / diversity.sum()
    return weights, entropy, diversity, x

# %% [markdown]
# ## 2. 대중교통점수 산출
#
# 버스와 지하철 승하차 데이터를 연도-자치구 단위로 합산한 뒤, 인구 대비 승차 강도, 하차 강도, 승하차 불균형을 계산합니다. 이후 기존 `교통_대중교통점수.ipynb`와 동일하게 연도별 백분위 점수의 평균을 사용합니다.

# %%
def transit_wide_to_yearly(df):
    work = df.copy()
    if 'gu_name' not in work.columns:
        work = work.rename(columns={work.columns[1]: 'gu_name'})

    value_cols = [c for c in work.columns if re.match(r'^\d{6}_(geton|getoff|etoff)$', str(c))]
    long_df = work[['gu_name'] + value_cols].melt(id_vars='gu_name', var_name='ym_type', value_name='value')
    long_df['year'] = long_df['ym_type'].astype(str).str[:4].astype(int)
    long_df['io'] = long_df['ym_type'].astype(str).str.split('_').str[-1].str.lower().replace({'etoff': 'getoff'})
    long_df['value'] = pd.to_numeric(long_df['value'], errors='coerce').fillna(0)

    yearly = (
        long_df.groupby(['year', 'gu_name', 'io'], as_index=False)['value'].sum()
        .pivot(index=['year', 'gu_name'], columns='io', values='value')
        .reset_index()
        .rename(columns={'geton': 'geton_total', 'getoff': 'getoff_total'})
    )
    for col in ['geton_total', 'getoff_total']:
        if col not in yearly.columns:
            yearly[col] = 0
    return yearly[['year', 'gu_name', 'geton_total', 'getoff_total']]

def population_long_from_garbage(path):
    raw = read_csv_smart(path)
    gu_col = pick_col(raw, candidates=['자치구'], fallback_index=0, label='자치구')
    pop_cols = [c for c in raw.columns if re.search(r'20\d{2}', str(c))]
    if not pop_cols:
        pop_cols = list(raw.columns[1:4])

    rows = []
    for col in pop_cols:
        year_match = re.search(r'20\d{2}', str(col))
        if not year_match:
            continue
        tmp = raw[[gu_col, col]].copy()
        tmp.columns = ['gu_name', 'population']
        tmp['year'] = int(year_match.group())
        tmp['population'] = pd.to_numeric(tmp['population'], errors='coerce')
        rows.append(tmp[['year', 'gu_name', 'population']])
    return pd.concat(rows, ignore_index=True)

bus = transit_wide_to_yearly(read_csv_smart(BUS_PATH))
subway = transit_wide_to_yearly(read_csv_smart(SUBWAY_PATH))
population = population_long_from_garbage(POPULATION_PATH)

transit = pd.concat([bus, subway], ignore_index=True)
transit = transit.groupby(['year', 'gu_name'], as_index=False)[['geton_total', 'getoff_total']].sum()
transit = transit.merge(population, on=['year', 'gu_name'], how='left')

eps = 1e-9
transit['board_intensity'] = transit['geton_total'] / (transit['population'] + eps)
transit['alight_intensity'] = transit['getoff_total'] / (transit['population'] + eps)
transit['imbalance'] = (transit['geton_total'] - transit['getoff_total']).abs() / (transit['geton_total'] + transit['getoff_total'] + eps)

transit['score_board'] = transit.groupby('year')['board_intensity'].transform(rank_100)
transit['score_alight'] = transit.groupby('year')['alight_intensity'].transform(rank_100)
transit['score_imbalance'] = transit.groupby('year')['imbalance'].transform(rank_100)
transit['transport_stress_score'] = transit[['score_board', 'score_alight', 'score_imbalance']].mean(axis=1)

transport_gu = (
    transit.groupby('gu_name', as_index=False)['transport_stress_score']
    .mean()
    .rename(columns={'transport_stress_score': 'transport_score'})
)
transport_gu.head()
# Out:
#   gu_name  transport_score
# 0     강남구        41.974026
# 1     강동구        53.558442
# 2     강북구        61.047619
# 3     강서구        58.051948
# 4     관악구        54.528139

# %% [markdown]
# ## 3. 출퇴근스트레스점수 집계
#
# 월별 출퇴근 스트레스 점수를 자치구 평균으로 집계합니다.

# %%
monthly = read_csv_smart(MONTHLY_PATH)
monthly_year_col = pick_col(monthly, candidates=['연도'], fallback_index=0, label='연도')
monthly_gu_col = pick_col(monthly, candidates=['자치구명'], fallback_index=3, label='자치구명')
commute_score_col = pick_col(monthly, candidates=['출퇴근스트레스점수'], fallback_index=10, label='출퇴근스트레스점수')

commute = monthly[[monthly_year_col, monthly_gu_col, commute_score_col]].copy()
commute.columns = ['year', 'gu_name', 'commute_stress_score']
commute['year'] = pd.to_numeric(commute['year'], errors='coerce').astype('Int64')
commute['commute_stress_score'] = pd.to_numeric(commute['commute_stress_score'], errors='coerce')

commute_year = commute.groupby(['year', 'gu_name'], as_index=False)['commute_stress_score'].mean()
commute_gu = commute.groupby('gu_name', as_index=False)['commute_stress_score'].mean()
commute_gu.head()
# Out:
#   gu_name  commute_stress_score
# 0     강남구             65.634708
# 1     강동구             35.381654
# 2     강북구             18.646856
# 3     강서구             36.328528
# 4     관악구             29.462275

# %% [markdown]
# ## 4. 주차점수와 민원점수 불러오기
#
# `parking_population_complaint_analysis.ipynb`에서 산출한 자치구 평균 요약 파일을 사용합니다.

# %%
parking_complaint = read_csv_smart(PARKING_COMPLAINT_PATH)
parking_complaint = parking_complaint[['gu_name', 'parking_score_100', 'complaint_score_100']].copy()
parking_complaint = parking_complaint.rename(columns={
    'parking_score_100': 'parking_score',
    'complaint_score_100': 'complaint_score',
})
parking_complaint.head()


QUARTERLY_PARKING_COMPLAINT_PATH = OUT_DIR / 'quarterly_parking_complaint_scores.csv'
parking_complaint_quarterly = read_csv_smart(QUARTERLY_PARKING_COMPLAINT_PATH)
parking_complaint_year = (
    parking_complaint_quarterly
    .groupby(['year', 'gu_name'], as_index=False)[['parking_score_100', 'complaint_score_100']]
    .mean()
    .rename(columns={
        'parking_score_100': 'parking_score',
        'complaint_score_100': 'complaint_score',
    })
)

# %% [markdown]
# ## 5. 연도별 교통 지표 점수 산출
#
# 네 지표를 `year + gu_name` 기준으로 결합한 뒤, 연도별로 0~1 정규화와 엔트로피 가중치 계산을 수행합니다. 이 표는 각 연도 안에서 자치구 간 상대적 교통 불편 수준을 25점 만점으로 보여줍니다.

# %%
indicator_cols = ['transport_score', 'commute_stress_score', 'parking_score', 'complaint_score']

transport_year = (
    transit[['year', 'gu_name', 'transport_stress_score']]
    .groupby(['year', 'gu_name'], as_index=False)['transport_stress_score']
    .mean()
    .rename(columns={'transport_stress_score': 'transport_score'})
)

yearly_base = (
    transport_year
    .merge(commute_year, on=['year', 'gu_name'], how='inner')
    .merge(parking_complaint_year, on=['year', 'gu_name'], how='inner')
)

yearly_results = []
yearly_weight_rows = []
for year, group in yearly_base.groupby('year'):
    group = group.copy().reset_index(drop=True)
    weights_y, entropy_y, diversity_y, normalized_y = entropy_weights(group[indicator_cols])

    for col in indicator_cols:
        group[f'{col}_norm'] = normalized_y[col] * 100
    group['traffic_entropy_raw_0_1'] = normalized_y.mul(weights_y, axis=1).sum(axis=1)
    group['traffic_score_25'] = (group['traffic_entropy_raw_0_1'] * 25).round(2)
    group['rank'] = group['traffic_score_25'].rank(method='min', ascending=False).astype(int)
    yearly_results.append(group)

    yearly_weight_rows.extend([
        {
            'year': year,
            'indicator': indicator,
            'entropy': entropy_y[indicator],
            'diversity': diversity_y[indicator],
            'weight': weights_y[indicator],
            'weight_percent': weights_y[indicator] * 100,
        }
        for indicator in indicator_cols
    ])

yearly_score_result = (
    pd.concat(yearly_results, ignore_index=True)
    .sort_values(['year', 'rank', 'gu_name'])
    .reset_index(drop=True)
)
yearly_weight_summary = pd.DataFrame(yearly_weight_rows)

display(yearly_weight_summary.round(4))
display(yearly_score_result[['year', 'rank', 'gu_name', 'traffic_score_25'] + indicator_cols])
# Out:
#     year             indicator  entropy  diversity  weight  weight_percent
# 0   2022       transport_score   0.9364     0.0636  0.1771         17.7104
# 1   2022  commute_stress_score   0.9245     0.0755  0.2104         21.0388
# 2   2022         parking_score   0.9488     0.0512  0.1427         14.2688
# 3   2022       complaint_score   0.8314     0.1686  0.4698         46.9821
# 4   2023       transport_score   0.9262     0.0738  0.2016         20.1569
# 5   2023  commute_stress_score   0.9217     0.0783  0.2139         21.3941
# 6   2023         parking_score   0.9496     0.0504  0.1376         13.7621
# 7   2023       complaint_score   0.8365     0.1635  0.4469         44.6869
# 8   2024       transport_score   0.9382     0.0618  0.1760         17.5973
# 9   2024  commute_stress_score   0.9257     0.0743  0.2116         21.1581
# 10  2024         parking_score   0.9415     0.0585  0.1667         16.6672
# 11  2024       complaint_score   0.8435     0.1565  0.4458         44.5774
#     year  rank gu_name  traffic_score_25  transport_score  \
# 0   2022     1      중구             16.23        60.380952
# 1   2022     2     마포구             16.07        68.870748
# 2   2022     3     서초구             15.44        52.598639
# 3   2022     4     강남구             15.42        44.081633
# 4   2022     5     용산구             13.63        45.850340
# ..   ...   ...     ...               ...              ...
# 70  2024    21     동작구              5.85        39.292517
# 71  2024    22     구로구              5.67        41.823129
# 72  2024    22     도봉구              5.67        47.374150
# 73  2024    24     성북구              5.31        36.244898
# 74  2024    25     금천구              1.90        40.244898
#
#     commute_stress_score  parking_score  complaint_score
# 0              26.710250      10.000000        85.575575
# 1              33.540280      32.807018        66.827413
# 2              43.635172      18.187135        72.795511
# 3              65.570418      28.947368        61.407410
# 4              22.065076      40.175439        74.591576
# ..                   ...            ...              ...
# 70             25.154923      72.807018        15.467342
# 71             26.999602      70.818713        11.427356
# 72             17.690953      74.327485        12.343627
# 73             28.081331      71.754386        12.392483
# 74             14.926125      18.771930        14.209571
#
# [75 rows x 8 columns]

# %% [markdown]
# ## 6. 네 지표 결합 및 엔트로피 가중치 계산
#
# 네 지표를 각각 0~1로 정규화한 뒤 엔트로피 가중치를 계산합니다. 최종 점수는 25점 만점이며, 높을수록 교통 문제가 큰 자치구로 해석합니다.

# %%
indicator_cols = ['transport_score', 'commute_stress_score', 'parking_score', 'complaint_score']

score_base = (
    transport_gu
    .merge(commute_gu, on='gu_name', how='inner')
    .merge(parking_complaint, on='gu_name', how='inner')
)

missing_count = 25 - score_base['gu_name'].nunique()
print(f'결합 자치구 수: {score_base["gu_name"].nunique()}개')
if missing_count:
    print(f'주의: 기준 25개 대비 {missing_count}개 자치구가 결합되지 않았습니다. 자치구명 인코딩/표기를 확인하세요.')

weights, entropy, diversity, normalized = entropy_weights(score_base[indicator_cols])

weight_summary = pd.DataFrame({
    'indicator': weights.index,
    'entropy': entropy.values,
    'diversity': diversity.values,
    'weight': weights.values,
    'weight_percent': weights.values * 100,
})

score_result = score_base.copy()
for col in indicator_cols:
    score_result[f'{col}_norm'] = normalized[col] * 100

score_result['traffic_entropy_raw_0_1'] = normalized.mul(weights, axis=1).sum(axis=1)
score_result['traffic_score_25'] = score_result['traffic_entropy_raw_0_1'] * 25
score_result['traffic_score_25'] = score_result['traffic_score_25'].round(2)
score_result['rank'] = score_result['traffic_score_25'].rank(method='min', ascending=False).astype(int)

score_result = score_result.sort_values(['rank', 'gu_name']).reset_index(drop=True)
display(weight_summary.round(4))
display(score_result[['rank', 'gu_name', 'traffic_score_25'] + indicator_cols].head(25))
# Out:
# 결합 자치구 수: 25개
#               indicator  entropy  diversity  weight  weight_percent
# 0       transport_score   0.9272     0.0728  0.2036         20.3643
# 1  commute_stress_score   0.9240     0.0760  0.2125         21.2542
# 2         parking_score   0.9489     0.0511  0.1430         14.2964
# 3       complaint_score   0.8424     0.1576  0.4409         44.0851
#     rank gu_name  traffic_score_25  transport_score  commute_stress_score  \
# 0      1      중구             15.88        59.974026             26.875147
# 1      2     마포구             15.87        67.480519             33.209960
# 2      3     용산구             14.24        42.727273             21.719300
# 3      4     강남구             13.84        41.974026             65.634708
# 4      5     서초구             13.82        47.766234             43.900723
# 5      6     강서구             13.69        58.051948             36.328528
# 6      7    영등포구             13.35        66.294372             36.541740
# 7      8     종로구             13.23        70.233766             27.077707
# 8      9     송파구             11.21        56.675325             53.680202
# 9     10     관악구              9.35        54.528139             29.462275
# 10    11     강동구              8.73        53.558442             35.381654
# 11    12     광진구              8.49        51.887446             25.956801
# 12    13     은평구              8.16        55.792208             27.952589
# 13    14    동대문구              7.82        51.826840             25.071708
# 14    15     강북구              7.39        61.047619             18.646856
# 15    16     중랑구              6.95        50.632035             22.459418
# 16    17    서대문구              6.47        47.523810             24.971396
# 17    18     양천구              6.36        36.649351             23.030893
# 18    19     노원구              5.97        40.017316             32.207849
# 19    20     도봉구              5.91        51.021645             17.319946
# 20    21     동작구              5.72        42.484848             24.995593
# 21    22     성동구              5.49        34.761905             24.348669
# 22    23     구로구              5.35        41.800866             26.593026
# 23    24     성북구              4.80        36.268398             28.067953
# 24    25     금천구              2.21        38.112554             15.037717
#
#     parking_score  complaint_score
# 0       10.000000        88.525192
# 1       34.873294        68.112743
# 2       52.183236        84.863859
# 3       27.504873        57.868102
# 4       17.680312        71.192644
# 5       41.812865        57.727673
# 6       58.771930        41.376113
# 7       11.481481        58.588555
# 8       64.463938        21.316274
# 9       72.846004        25.764141
# 10      64.970760        20.418333
# 11      59.746589        29.085550
# 12      61.189084        20.839619
# 13      49.766082        28.224382
# 14      72.884990        13.203581
# 15      89.961014        12.452472
# 16      60.916179        19.562894
# 17      88.752437        22.470618
# 18      86.335283        10.170038
# 19      79.863548        11.672785
# 20      73.196881        15.466079
# 21      82.358674        19.280568
# 22      72.962963        12.359338
# 23      74.171540        12.671211
# 24      30.272904        15.995273

# %% [markdown]
# ## 7. PCA 및 CRITIC 가중치 비교
#
# 메인 교통점수는 엔트로피 가중치 기준을 유지하되, 같은 4개 지표에 대해 PCA와 CRITIC 방식의 가중치도 함께 계산해 비교합니다. PCA는 첫 번째 주성분의 절대 적재량을 가중치로 환산하고, CRITIC은 지표의 변동성과 지표 간 상관 충돌 정보를 함께 반영합니다.

# %%
def pca_weights(matrix):
    x = matrix.astype(float).copy()
    std = x.std(axis=0, ddof=0).replace(0, 1)
    z = (x - x.mean(axis=0)) / std

    cov = np.cov(z, rowvar=False)
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    order = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]

    if np.isclose(eigenvalues.sum(), 0):
        weights = pd.Series(1 / matrix.shape[1], index=matrix.columns)
        first_pc_loadings = weights.copy()
        explained_variance_ratio = 0
        return weights, first_pc_loadings, explained_variance_ratio

    first_pc_loadings = pd.Series(np.abs(eigenvectors[:, 0]), index=matrix.columns)
    weights = first_pc_loadings / first_pc_loadings.sum()
    explained_variance_ratio = eigenvalues[0] / eigenvalues.sum()
    return weights, first_pc_loadings, explained_variance_ratio


def critic_weights(matrix):
    x = matrix.astype(float).copy()
    std = x.std(axis=0, ddof=0)
    corr = x.corr().fillna(0)
    conflict = (1 - corr).sum(axis=1)
    information = std * conflict

    if np.isclose(information.sum(), 0):
        weights = pd.Series(1 / len(information), index=information.index)
    else:
        weights = information / information.sum()
    return weights, std, conflict, information


pca_w, pca_loading, pca_explained_ratio = pca_weights(normalized[indicator_cols])
critic_w, critic_std, critic_conflict, critic_info = critic_weights(normalized[indicator_cols])

comparison_weight_summary = pd.concat([
    weight_summary.assign(method='entropy')[['method', 'indicator', 'weight', 'weight_percent']],
    pd.DataFrame({
        'method': 'pca',
        'indicator': pca_w.index,
        'weight': pca_w.values,
        'weight_percent': pca_w.values * 100,
        'pca_abs_loading': pca_loading.values,
        'pca_explained_variance_ratio': pca_explained_ratio,
    }),
    pd.DataFrame({
        'method': 'critic',
        'indicator': critic_w.index,
        'weight': critic_w.values,
        'weight_percent': critic_w.values * 100,
        'critic_std': critic_std.values,
        'critic_conflict': critic_conflict.values,
        'critic_information': critic_info.values,
    }),
], ignore_index=True)

weight_pivot = comparison_weight_summary.pivot_table(
    index='indicator',
    columns='method',
    values='weight_percent',
).reindex(indicator_cols)

comparison_score_result = score_base[['gu_name'] + indicator_cols].copy()
comparison_score_result['traffic_score_25'] = (
    normalized[indicator_cols].mul(weights, axis=1).sum(axis=1) * 25
).round(2)
comparison_score_result['traffic_score_25_pca'] = (
    normalized[indicator_cols].mul(pca_w, axis=1).sum(axis=1) * 25
).round(2)
comparison_score_result['traffic_score_25_critic'] = (
    normalized[indicator_cols].mul(critic_w, axis=1).sum(axis=1) * 25
).round(2)

comparison_score_result['rank_entropy'] = comparison_score_result['traffic_score_25'].rank(method='min', ascending=False).astype(int)
comparison_score_result['rank_pca'] = comparison_score_result['traffic_score_25_pca'].rank(method='min', ascending=False).astype(int)
comparison_score_result['rank_critic'] = comparison_score_result['traffic_score_25_critic'].rank(method='min', ascending=False).astype(int)
comparison_score_result = comparison_score_result.sort_values(['rank_entropy', 'gu_name']).reset_index(drop=True)

print(f'PCA 1주성분 설명분산비율: {pca_explained_ratio:.2%}')
display(comparison_weight_summary.round(4))
display(weight_pivot.round(2))
display(comparison_score_result[[
    'gu_name',
    'rank_entropy', 'traffic_score_25',
    'rank_pca', 'traffic_score_25_pca',
    'rank_critic', 'traffic_score_25_critic',
]].head(25))
# Out:
# PCA 1주성분 설명분산비율: 55.80%
#      method             indicator  weight  weight_percent  pca_abs_loading  \
# 0   entropy       transport_score  0.2036         20.3643              NaN
# 1   entropy  commute_stress_score  0.2125         21.2542              NaN
# 2   entropy         parking_score  0.1430         14.2964              NaN
# 3   entropy       complaint_score  0.4409         44.0851              NaN
# 4       pca       transport_score  0.2120         21.2016           0.4130
# 5       pca  commute_stress_score  0.1747         17.4729           0.3404
# 6       pca         parking_score  0.3088         30.8771           0.6015
# 7       pca       complaint_score  0.3045         30.4483           0.5931
# 8    critic       transport_score  0.2201         22.0138              NaN
# 9    critic  commute_stress_score  0.1677         16.7722              NaN
# 10   critic         parking_score  0.3554         35.5355              NaN
# 11   critic       complaint_score  0.2568         25.6785              NaN
#
#     pca_explained_variance_ratio  critic_std  critic_conflict  \
# 0                            NaN         NaN              NaN
# 1                            NaN         NaN              NaN
# 2                            NaN         NaN              NaN
# 3                            NaN         NaN              NaN
# 4                          0.558         NaN              NaN
# 5                          0.558         NaN              NaN
# 6                          0.558         NaN              NaN
# 7                          0.558         NaN              NaN
# 8                            NaN      0.2805           2.9251
# 9                            NaN      0.2165           2.8881
# 10                           NaN      0.2938           4.5082
# 11                           NaN      0.3089           3.0981
#
#     critic_information
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8               0.8205
# 9               0.6252
# 10              1.3245
# 11              0.9571
# method                critic  entropy    pca
# indicator
# transport_score        22.01    20.36  21.20
# commute_stress_score   16.77    21.25  17.47
# parking_score          35.54    14.30  30.88
# complaint_score        25.68    44.09  30.45
#    gu_name  rank_entropy  traffic_score_25  rank_pca  traffic_score_25_pca  \
# 0       중구             1             15.88         6                 12.40
# 1      마포구             2             15.87         1                 14.49
# 2      용산구             3             14.24         3                 13.10
# 3      강남구             4             13.84         8                 11.77
# 4      서초구             5             13.82        10                 11.10
# 5      강서구             6             13.69         4                 13.01
# 6     영등포구             7             13.35         2                 14.31
# 7      종로구             8             13.23         9                 11.19
# 8      송파구             9             11.21         5                 12.95
# 9      관악구            10              9.35         7                 11.78
# 10     강동구            11              8.73        12                 10.87
# 11     광진구            12              8.49        15                 10.14
# 12     은평구            13              8.16        14                 10.24
# 13    동대문구            14              7.82        19                  9.01
# 14     강북구            15              7.39        13                 10.60
# 15     중랑구            16              6.95        11                 10.95
# 16    서대문구            17              6.47        22                  8.59
# 17     양천구            18              6.36        16                  9.77
# 18     노원구            19              5.97        17                  9.64
# 19     도봉구            20              5.91        18                  9.52
# 20     동작구            21              5.72        21                  8.63
# 21     성동구            22              5.49        20                  8.67
# 22     구로구            23              5.35        23                  8.34
# 23     성북구            24              4.80        24                  7.79
# 24     금천구            25              2.21        25                  3.02
#
#     rank_critic  traffic_score_25_critic
# 0            10                    11.31
# 1             2                    14.09
# 2             5                    12.60
# 3            11                    11.16
# 4            18                    10.26
# 5             4                    12.81
# 6             1                    14.65
# 7            16                    10.63
# 8             3                    13.57
# 9             6                    12.52
# 10            9                    11.55
# 11           15                    10.64
# 12           12                    10.89
# 13           21                     9.38
# 14            8                    11.61
# 15            7                    12.15
# 16           22                     9.23
# 17           14                    10.71
# 18           13                    10.72
# 19           17                    10.60
# 20           20                     9.48
# 21           19                     9.56
# 22           23                     9.22
# 23           24                     8.65
# 24           25                     3.25

# %% [markdown]
# ## 8. 결과 저장

# %%
weight_summary.to_csv(WEIGHT_PATH, index=False, encoding='utf-8-sig')
score_result.to_csv(FINAL_SCORE_PATH, index=False, encoding='utf-8-sig')
yearly_score_result.to_csv(FINAL_YEARLY_SCORE_PATH, index=False, encoding='utf-8-sig')

print(f'가중치 저장: {WEIGHT_PATH}')
print(f'최종 점수 저장: {FINAL_SCORE_PATH}')
print(f'연도별 최종 점수 저장: {FINAL_YEARLY_SCORE_PATH}')
# Out:
# 가중치 저장: C:\8ssible-Healing-Seoul-Analysis\branch_SG\traffic_analystic\outputs\traffic_entropy_weights.csv
# 최종 점수 저장: C:\8ssible-Healing-Seoul-Analysis\branch_SG\traffic_analystic\outputs\gu_traffic_entropy_score_25.csv
# 연도별 최종 점수 저장: C:\8ssible-Healing-Seoul-Analysis\branch_SG\traffic_analystic\outputs\gu_traffic_entropy_score_25_by_year.csv
