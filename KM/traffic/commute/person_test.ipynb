# %%
import pandas as pd

df = pd.read_csv("monthly_scores_문헌기반_서울.csv")
df
# Out:
#         연도   월  자치구코드 자치구명     총이동인구수     평균이동시간         총이동시간  유입인구_norm  \
# 0     2022   1  11240  송파구  563446.22  44.981302  2.534454e+07   1.000000
# 1     2022   1  11230  강남구  556713.94  44.413550  2.472564e+07   0.988052
# 2     2022   1  11160  강서구  394817.34  42.776841  1.688904e+07   0.700717
# 3     2022   1  11220  서초구  376024.14  43.854159  1.649022e+07   0.667363
# 4     2022   1  11110  노원구  381864.84  41.603744  1.588701e+07   0.677729
# ...    ...  ..    ...  ...        ...        ...           ...        ...
# 8345  2024  11  11070  중랑구  409138.46  49.965944  2.044299e+07   0.379309
# 8346  2024  11  11150  양천구  414260.05  48.609976  2.013717e+07   0.384058
# 8347  2024  11  11090  강북구  334225.65  51.275235  1.713750e+07   0.309841
# 8348  2024  11  11100  도봉구  321488.85  50.492173  1.623267e+07   0.298030
# 8349  2024  11  11180  금천구  226976.74  52.842439  1.199400e+07   0.210388
#
#       평균이동시간_norm  총이동시간_norm  출퇴근스트레스점수  가중치_유입인구  가중치_평균이동시간  가중치_총이동시간  \
# ...
