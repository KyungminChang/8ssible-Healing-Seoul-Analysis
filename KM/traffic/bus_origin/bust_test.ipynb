# %%
import pandas as pd

df = pd.read_csv("monthly_aggregates_bus_2022/bus_30min_monthly_2022_04.csv")

df
# Out:
#         YEAR  MONTH  HOUR  HALF_HOUR  STATION_ID     STATION_NM  GETON_CNT  \
# 0       2022      4     0          0         392           종로1가         98
# 1       2022      4     0          0         813       길음뉴타운8단지         14
# 2       2022      4     0          0         813  미화약국.길음뉴타운8단지          2
# 3       2022      4     0          0         855        여의도환승센터         85
# 4       2022      4     0          0        1911         범일운수종점          2
# ...      ...    ...   ...        ...         ...            ...        ...
# 715698  2022      5     3         30     9036972    신촌오거리.현대백화점         19
# 715699  2022      5     3         30     9036973         동교동삼거리          2
# 715700  2022      5     3         30     9036974          홍대입구역         50
# 715701  2022      5     3         30     9606597  동명여고.천주교불광동성당          0
# 715702  2022      5     3         30     9636390    박석고개.신도고등학교          0
#
#         GETOFF_CNT
# 0                3
# 1                1
# ...
