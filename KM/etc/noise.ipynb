# %%
import pandas as pd

df = pd.read_csv("120_서울시 IOT 복합 센서(환경정보)_PUBDATA_20250701.csv", encoding='cp949')
df
df['region'].value_counts()
# Out:
# region
# residential_area       12640
# roads_and_parks         2417
# traditional_markets      856
# industrial_area          775
# main_street              731
# commercial_area          581
# parks                    127
# public_facilities         78
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['모델명', '시리얼', 'sensing_time', 'region', 'autonomous_district',
#        'administrative_district', 'max_temp (℃)', 'avg_temp (℃)',
#        'min_temp (℃)', 'max_humi (%)', 'avg_humi (%)', 'min_humi (%)',
#        'max_wind_speed (m/s)', 'avg_wind_speed (m/s)', 'min_wind_speed (m/s)',
#        'max_wind_dire (m/s)', 'avg_wind_dire (m/s)', 'min_wind_dire (m/s)',
#        'max_inte_illu (lux)', 'avg_inte_illu (lux)', 'min_inte_illu (lux)',
#        'max_ultra_rays (UV)', 'avg_ultra_rays (UV)', 'min_ultra_rays (UV)',
#        'max_noise (dB )', 'avg_noise (dB )', 'min_noise (dB )',
#        'max_vibr_x (mm/s)', 'avg_vibr_x (mm/s)', 'min_vibr_x (mm/s)',
#        'max_vibr_y (mm/s)', 'avg_vibr_y (mm/s)', 'min_vibr_y (mm/s)',
#        'max_vibr_z (mm/s)', 'avg_vibr_z (mm/s)', 'min_vibr_z (mm/s)',
#        'max_effe_temp (℃)', 'avg_effe_temp (℃)', 'min_effe_temp (℃)',
#        'max_no2 (ppm)', 'avg_no2 (ppm)', 'min_no2 (ppm)', 'max_co (ppm)',
# ...

# %%
df['모델명'].value_counts()
# Out:
# 모델명
# SDOT001    18205
# Name: count, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
